# %%
from google.colab import drive
drive.mount("/content/gdrive/")
# Out:
# Mounted at /content/gdrive/

# %%
import numpy as np
import cv2
# !pip install patchify 
from patchify import patchify

train_ind = ['0_0', '0_2', '0_3', '0_4', '0_5', '0_6', '0_7', '0_8', '0_10', '0_11', '0_13', '0_14', '1_0', '1_1', '1_2', '1_3', '1_5', '1_8', '1_10', '1_11', '1_12', '1_13', '1_15', '2_0', '2_2', '2_4', '2_5', '2_6', '2_7', '2_8', '2_9', '2_10', '2_11', '2_12', '2_13', '2_15', '3_1', '3_2', '3_4', '3_5', '3_7', '3_8', '3_9', '3_10', '3_11', '3_12', '3_13', '3_14', '3_15', '4_0', '4_1', '4_2', '4_3', '4_4', '4_6', '4_8', '4_10', '4_12', '4_13', '4_14', '4_15', '5_0', '5_1', '5_3', '5_5', '5_6', '5_7', '5_8', '5_9', '5_11', '5_12', '5_15', '6_0', '6_1', '6_2', '6_4', '6_5', '6_6', '6_7', '6_9', '6_10', '6_12', '6_14', '6_15', '7_1', '7_3', '7_4', '7_5', '7_6', '7_7', '7_8', '7_9', '7_11', '7_13', '8_0', '8_1', '8_2', '8_4', '8_5', '8_6', '8_7', '8_8', '8_9', '8_10', '8_11', '8_12', '8_14', '8_15', '9_0', '9_3', '9_4', '9_5', '9_6', '9_8', '9_10', '9_11', '9_12', '9_13', '9_14', '9_15', '10_1', '10_2', '10_3', '10_5', '10_9', '10_10', '10_11', '10_12', '10_13', '10_14', '10_15', '11_0', '11_1', '11_3', '11_4', '11_5', '11_6', '11_7', '11_8', '11_9', '11_10', '11_11', '11_12', '11_13', '11_14', '12_0', '12_1', '12_3', '12_4', '12_5', '12_6', '12_7', '12_8', '12_9', '12_10', '12_11', '12_12', '12_13', '12_14', '12_15', '13_0', '13_1', '13_2', '13_3', '13_4', '13_5', '13_6', '13_7', '13_9', '13_10', '13_11', '13_12', '13_14', '13_15', '14_0', '14_1', '14_2', '14_3', '14_4', '14_5', '14_6', '14_7', '14_9', '14_10', '14_11', '14_13', '14_14', '14_15', '15_1', '15_2', '15_3', '15_4', '15_5', '15_6', '15_7', '15_10', '15_12', '15_13', '15_14', '15_15']
val_ind = ['9_9','0_15','14_12','0_1','2_14','6_8','1_14','0_9','1_4','1_6','1_7','1_9','10_0','10_4','10_6','10_8','11_15','11_2','13_13','13_8','14_8','15_0','15_11','15_8','15_9','2_3','3_0','3_3','3_6','3_6','4_11','4_7','4_9','5_10','5_13','5_14','5_2','5_4','6_11','6_13','6_3','7_0','7_10','7_2','8_13','8_3','9_1','9_2','9_7','7_12','7_14']
manual_ind = ['0_12','2_1','4_5','7_15','10_7', '12_2']
#os.mkdir(gdrive/MyDrive/UNET/1024_patches/train_masks/2016/)
for i in train_ind:
  print(i)
  train_a_16 = np.load("gdrive/MyDrive/GEE_2016_np/"+i+".npy")
  train_a_19 = np.load("gdrive/MyDrive/GEE_2019_np/"+i+".npy")
  train_b_16 = np.load("gdrive/MyDrive/GEE_Dynamic_2016_three_class_np_label/"+i+".npy")
  train_b_19 = np.load("gdrive/MyDrive/GEE_Dynamic_2019_three_class_np_label/"+i+".npy")


  train_a_16 = cv2.resize(train_a_16, (4096,4096))
  train_a_19 = cv2.resize(train_a_19, (4096,4096))
  new_train_b_16 = cv2.resize(train_b_16, (4096,4096))
  new_train_b_19 = cv2.resize(train_b_19, (4096,4096))

  patch_img = patchify(new_train_b_16, (1024, 1024, 3), step=1024)
            
  for j in range(patch_img.shape[0]):           
    for k in range(patch_img.shape[1]):
      # patches are located like a grid. use (j, k) indices to extract single patched image
      single_patch_img = patch_img[j, k]
      single_patch_img = single_patch_img[0]
      single_patch_img = cv2.resize(single_patch_img, (256,256))
      np.save('gdrive/MyDrive/UNET/1024_patches/train_masks/2016/'+i+'_'+str(j)+str(k)+'.npy', single_patch_img)
  
  
  patch_img = patchify(new_train_b_19, (1024, 1024, 3), step=1024)
            
  for j in range(patch_img.shape[0]):           
    for k in range(patch_img.shape[1]):
      single_patch_img = patch_img[j, k]
      single_patch_img = single_patch_img[0]
      single_patch_img = cv2.resize(single_patch_img, (256,256))
      np.save('gdrive/MyDrive/UNET/1024_patches/train_masks/2019/'+i+'_'+str(j)+str(k)+'.npy', single_patch_img)

  patch_img = patchify(train_a_16, (1024, 1024, 3), step=1024)
           
  for j in range(patch_img.shape[0]):           
    for k in range(patch_img.shape[1]):
      # patches are located like a grid. use (j, k) indices to extract single patched image
      single_patch_img = patch_img[j, k]
      single_patch_img = single_patch_img[0]
      single_patch_img = cv2.resize(single_patch_img, (256,256))
      np.save('gdrive/MyDrive/UNET/1024_patches/train_images/2016/'+i+'_'+str(j)+str(k)+'.npy', single_patch_img)
  
  patch_img = patchify(train_a_19, (1024, 1024, 3), step=1024)
            
  for j in range(patch_img.shape[0]):           
    for k in range(patch_img.shape[1]):
      # patches are located like a grid. use (j, k) indices to extract single patched image
      single_patch_img = patch_img[j, k]
      single_patch_img = single_patch_img[0]
      single_patch_img = cv2.resize(single_patch_img, (256,256))
      np.save('gdrive/MyDrive/UNET/1024_patches/train_images/2019/'+i+'_'+str(j)+str(k)+'.npy', single_patch_img)

# %%
for i in val_ind:
  print(i)
  train_a_16 = np.load("gdrive/MyDrive/GEE_2016_np/"+i+".npy")
  train_a_19 = np.load("gdrive/MyDrive/GEE_2019_np/"+i+".npy")
  train_b_16 = np.load("gdrive/MyDrive/GEE_Dynamic_2016_three_class_np_label/"+i+".npy")
  train_b_19 = np.load("gdrive/MyDrive/GEE_Dynamic_2019_three_class_np_label/"+i+".npy")


  train_a_16 = cv2.resize(train_a_16, (4096,4096))
  train_a_19 = cv2.resize(train_a_19, (4096,4096))
  new_train_b_16 = cv2.resize(train_b_16, (4096,4096))
  new_train_b_19 = cv2.resize(train_b_19, (4096,4096))

  patch_img = patchify(new_train_b_16, (1024, 1024, 3), step=1024)
  #print(patch_img.shape)
            
  for j in range(patch_img.shape[0]):           
    for k in range(patch_img.shape[1]):
      # patches are located like a grid. use (j, k) indices to extract single patched image
      single_patch_img = patch_img[j, k]
      single_patch_img = single_patch_img[0]
      single_patch_img = cv2.resize(single_patch_img, (256,256))
      np.save('gdrive/MyDrive/UNET/1024_patches/val_masks/2016/'+i+'_'+str(j)+str(k)+'.npy', single_patch_img)
  
  
  patch_img = patchify(new_train_b_19, (1024, 1024, 3), step=1024)
            
  for j in range(patch_img.shape[0]):           
    for k in range(patch_img.shape[1]):
      single_patch_img = patch_img[j, k]
      single_patch_img = single_patch_img[0]
      single_patch_img = cv2.resize(single_patch_img, (256,256))
      np.save('gdrive/MyDrive/UNET/1024_patches/val_masks/2019/'+i+'_'+str(j)+str(k)+'.npy', single_patch_img)

  patch_img = patchify(train_a_16, (1024, 1024, 3), step=1024)
           
  for j in range(patch_img.shape[0]):           
    for k in range(patch_img.shape[1]):
      # patches are located like a grid. use (j, k) indices to extract single patched image
      single_patch_img = patch_img[j, k]
      single_patch_img = single_patch_img[0]
      single_patch_img = cv2.resize(single_patch_img, (256,256))
      np.save('gdrive/MyDrive/UNET/1024_patches/val_images/2016/'+i+'_'+str(j)+str(k)+'.npy', single_patch_img)
  
  patch_img = patchify(train_a_19, (1024, 1024, 3), step=1024)
            
  for j in range(patch_img.shape[0]):           
    for k in range(patch_img.shape[1]):
      # patches are located like a grid. use (j, k) indices to extract single patched image
      single_patch_img = patch_img[j, k]
      single_patch_img = single_patch_img[0]
      single_patch_img = cv2.resize(single_patch_img, (256,256))
      np.save('gdrive/MyDrive/UNET/1024_patches/val_images/2019/'+i+'_'+str(j)+str(k)+'.npy', single_patch_img)

# %%
for i in manual_ind:
  print(i)
  train_a_16 = np.load("gdrive/MyDrive/GEE_2016_np/"+i+".npy")
  train_a_19 = np.load("gdrive/MyDrive/GEE_2019_np/"+i+".npy")
  train_b_16 = np.load("gdrive/MyDrive/GEE_Dynamic_2016_three_class_np_label/"+i+".npy")
  train_b_19 = np.load("gdrive/MyDrive/GEE_Dynamic_2019_three_class_np_label/"+i+".npy")


  train_a_16 = cv2.resize(train_a_16, (4096,4096))
  train_a_19 = cv2.resize(train_a_19, (4096,4096))
  new_train_b_16 = cv2.resize(train_b_16, (4096,4096))
  new_train_b_19 = cv2.resize(train_b_19, (4096,4096))

  patch_img = patchify(new_train_b_16, (1024, 1024, 3), step=1024)
  #print(patch_img.shape)
           
  for j in range(patch_img.shape[0]):           
    for k in range(patch_img.shape[1]):
      # patches are located like a grid. use (j, k) indices to extract single patched image
      single_patch_img = patch_img[j, k]
      single_patch_img = single_patch_img[0]
      single_patch_img = cv2.resize(single_patch_img, (256,256))
      np.save('gdrive/MyDrive/UNET/1024_patches/man_masks/2016/'+i+'_'+str(j)+str(k)+'.npy', single_patch_img)
  
  
  patch_img = patchify(new_train_b_19, (1024, 1024, 3), step=1024)
            
  for j in range(patch_img.shape[0]):           
    for k in range(patch_img.shape[1]):
      single_patch_img = patch_img[j, k]
      single_patch_img = single_patch_img[0]
      single_patch_img = cv2.resize(single_patch_img, (256,256))
      np.save('gdrive/MyDrive/UNET/1024_patches/man_masks/2019/'+i+'_'+str(j)+str(k)+'.npy', single_patch_img)

  patch_img = patchify(train_a_16, (1024, 1024, 3), step=1024)
           
  for j in range(patch_img.shape[0]):           
    for k in range(patch_img.shape[1]):
      # patches are located like a grid. use (j, k) indices to extract single patched image
      single_patch_img = patch_img[j, k]
      single_patch_img = single_patch_img[0]
      single_patch_img = cv2.resize(single_patch_img, (256,256))
      np.save('gdrive/MyDrive/UNET/1024_patches/man_images/2016/'+i+'_'+str(j)+str(k)+'.npy', single_patch_img)
  
  patch_img = patchify(train_a_19, (1024, 1024, 3), step=1024)
            
  for j in range(patch_img.shape[0]):           
    for k in range(patch_img.shape[1]):
      # patches are located like a grid. use (j, k) indices to extract single patched image
      single_patch_img = patch_img[j, k]
      single_patch_img = single_patch_img[0]
      single_patch_img = cv2.resize(single_patch_img, (256,256))
      np.save('gdrive/MyDrive/UNET/1024_patches/man_images/2019/'+i+'_'+str(j)+str(k)+'.npy', single_patch_img)
